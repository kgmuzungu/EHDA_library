# %% [markdown]
# #	Concatenating
# #	AUTHOR: 乔昂 - jueta
# #	DATE: 13/12/2022

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt


file_name = "exp9_corrected.feather"
data = pd.read_feather(file_name)
data.head()
# Out:
#                    name                                             sample  \
# 0  setup/liquid/ethanol  [5.786163806915283, 0.5031446218490601, 1.0062...
# 1  setup/liquid/ethanol  [-0.5031446218490601, -2.264150857925415, -0.5...
# 2  setup/liquid/ethanol  [-0.5031446218490601, -0.5031446218490601, 6.5...
# 3  setup/liquid/ethanol  [0.7547169923782349, 1.257861614227295, 5.5345...
# 4  setup/liquid/ethanol  [-1.0062892436981201, 10.817609786987305, -9.3...
#
#       flow_rate  voltage   current PS temperature humidity    date and time  \
# 0  2.777800e-09  3001.36  -1.8675e-08          10       10  Mon_05 Dec 2022
# 1  2.777800e-09  3001.36  -1.8675e-08          10       10  Mon_05 Dec 2022
# 2  2.777800e-09  3001.36  -1.8675e-08          10       10  Mon_05 Dec 2022
# 3  2.777800e-09  3001.36  -1.8675e-08          10       10  Mon_05 Dec 2022
# 4  2.777800e-09  3001.36  -1.8675e-08          10       10  Mon_05 Dec 2022
#
# ...

# %%
exp1 = pd.read_feather("exp1_corrected.feather")
exp2 = pd.read_feather("exp2_corrected.feather")
exp3 = pd.read_feather("exp3_corrected.feather")
exp4 = pd.read_feather("exp4_corrected.feather")
exp5 = pd.read_feather("exp5_corrected.feather")
exp6 = pd.read_feather("exp6_corrected.feather")
exp7 = pd.read_feather("exp7_corrected.feather")
exp8 = pd.read_feather("exp8_corrected.feather")
exp9 = pd.read_feather("exp9_corrected.feather")
