# %% [markdown]
# ## Transforming JSON raw data acquired to feather

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
df = pd.read_json("Data/data.json", orient="index")

# %%
df.head()
# Out:
#                           name  \
# sample 0  setup/liquid/ethanol
# sample 1  setup/liquid/ethanol
# sample 2  setup/liquid/ethanol
# sample 3  setup/liquid/ethanol
# sample 4  setup/liquid/ethanol
#
#                                                     current  flow_rate  \
# sample 0  [-3.018867969512939, -4.52830171585083, 3.2704...       0.59
# sample 1  [2.01257848739624, 11.572327613830566, 12.5786...       0.59
# sample 2  [-16.8553466796875, -16.352201461791992, -18.8...       0.59
# sample 3  [-0.5031446218490601, 2.01257848739624, 0.5031...       0.59
# sample 4  [0.7547169923782341, -0.5031446218490601, -4.2...       0.59
#
#           voltage    current_PS  temperature  humidity  \
# sample 0  3001.69  1.981140e-08          0.0        30
# sample 1  3001.69  1.981140e-08         19.8        30
# sample 2  3001.69  1.981140e-08         19.8        30
# sample 3  3001.69  1.981140e-08         19.8        30
# sample 4  3001.69  1.981140e-08         19.8        30
#
# ...

# %%
df = df.reset_index()

# %%
df.to_feather("Data/map_23-05-04_1.feather")
