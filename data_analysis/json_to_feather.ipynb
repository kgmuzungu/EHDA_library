# %% [markdown]
# ## Transforming JSON raw data acquired to feather

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
df = pd.read_json("Data/Joao-LPDB_2023-04-24/control1/data.json", orient="index")

# %%
df.head()
# Out:
#                           name  \
# sample 0  setup/liquid/ethanol
# sample 1  setup/liquid/ethanol
# sample 2  setup/liquid/ethanol
# sample 3  setup/liquid/ethanol
# sample 4  setup/liquid/ethanol
#
#                                                     current  flow_rate  \
# sample 0  [-1.00628924369812, -7.044025421142578, -2.515...        0.5
# sample 1  [2.51572322845459, -2.51572322845459, 7.044025...        0.5
# sample 2  [-1.257861614227295, 0.0, -2.264150857925415, ...        0.5
# sample 3  [-1.257861614227295, 0.0, 2.51572322845459, 3....        0.5
# sample 4  [-7.044025421142578, 0.0, 5.786163806915283, -...        0.5
#
#           voltage    current_PS  temperature  humidity  \
# sample 0  3001.64 -4.014250e-09          0.0         0
# sample 1  3001.64 -4.014250e-09         20.0         0
# sample 2  3001.64 -4.014250e-09         20.0        54
# sample 3  3099.10  6.275080e-07         20.0        54
# sample 4  3197.71  8.585250e-07         20.0        54
#
# ...

# %%
df = df.reset_index()

# %%
df.to_feather("Data/control_24-04.feather")
